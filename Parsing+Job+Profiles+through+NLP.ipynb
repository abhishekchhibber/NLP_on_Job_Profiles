# %%
import os
import re

# %%
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.util import ngrams
from nltk.util import bigrams
from nltk.collocations import *

# %%
import pandas as pd
import numpy as np

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read the text

# %%
path =  "path_of_txt_file"

# %%
os.chdir(path)

# %%
with open('data_analyst.txt') as f:
    data = f.read()

# %% [markdown]
# ### Convert the text to lowercase

# %%
data = data.lower()

# %% [markdown]
# ### Finding total number of words and punctuation in the text

# %%
tokens = nltk.word_tokenize(data)

# %%
print(len(tokens))
# Out:
# 9848

# %% [markdown]
# ### Removing Stop-words

# %%
stop = set(stopwords.words('english'))

# %%
token_list1 = [ ]

# %%
for token in tokens:
    if token not in stop:
        token_list1.append(token)

# %%
print(len(token_list1))
# Out:
# 7149

# %% [markdown]
# ### Removing punctuation

# %%
punctuation = re.compile(r'[-.?!,":;()|0-9]')

# %%
token_list2 = [ ]

# %%
for token in token_list1:
    word = punctuation.sub("", token)
    if len(word)>0:
        token_list2.append(word)

# %%
print(len(token_list2))
# Out:
# 6359

# %% [markdown]
# ### Finding POS tags of words

# %%
tokens_pos_tag = nltk.pos_tag(token_list2)

# %%
pos_df = pd.DataFrame(tokens_pos_tag, columns = ('word','POS'))

# %%
pos_df.head()
# Out:
#           word  POS
# 0     maintain   NN
# 1     validate   NN
# 2       equity   NN
# 3  fixedincome  VBP
# 4     security   NN

# %%
pos_sum = pos_df.groupby('POS', as_index=False).count() # group by POS tags

# %%
pos_sum.sort_values(['word'], ascending=[False]) # in descending order of number of words per tag
# Out:
#     POS  word
# 10   NN  2309
# 12  NNS  1304
# 6    JJ  1147
# 21  VBG   437
# 23  VBP   402
# 15   RB   184
# 22  VBN   131
# 19   VB   107
# 24  VBZ    94
# 20  VBD    93
# 5    IN    37
# 2    CC    20
# 9    MD    19
# 11  NNP    18
# 4    FW    13
# 3    CD    13
# 8   JJS     7
# 16  RBR     7
# 14  PRP     6
# 7   JJR     4
# 13  POS     2
# 0     #     2
# 1    ''     1
# 17  RBS     1
# 18   RP     1

# %%
print (nltk.pos_tag(token_list2))
# Out:
# [('maintain', 'NN'), ('validate', 'NN'), ('equity', 'NN'), ('fixedincome', 'VBP'), ('security', 'NN'), ('data', 'NNS'), ('including', 'VBG'), ('pricing', 'NN'), ('ensure', 'VB'), ('consistency', 'NN'), ('investment', 'NN'), ('data', 'NNS'), ('across', 'IN'), ('multiple', 'JJ'), ('business', 'NN'), ('applications', 'NNS'), ('databases', 'VBZ'), ('work', 'NN'), ('closely', 'RB'), ('business', 'NN'), ('teams', 'NNS'), ('ensure', 'VB'), ('data', 'NNS'), ('integrity', 'NN'), ('define', 'NN'), ('process', 'NN'), ('improvements', 'NNS'), ('respond', 'VB'), ('data', 'NNS'), ('requests', 'NNS'), ('support', 'VBP'), ('analytic', 'JJ'), ('investing', 'VBG'), ('portfolio', 'NN'), ('management', 'NN'), ('functions', 'NNS'), ('analyze', 'VBP'), ('exception', 'NN'), ('reports', 'NNS'), ('followup', 'JJ'), ('ensure', 'VB'), ('timely', 'JJ'), ('resolution', 'NN'), ('analyze', 'IN'), ('user', 'JJ'), ('requests', 'NNS'), ('respond', 'VBP'), ('data', 'NNS'), ('issues', 'NNS'), ('assessment', 'JJ'), ('resolution', 'NN'), ('root', 'NN'), ('cause', 'NN'), ('work', 'NN'), ('business', 'NN'), ('development', 'NN'), ('extensive', 'JJ'), ('list', 'NN'), ('data', 'NNS'), ('requirements', 'NNS'), ('needed', 'VBD'), ('ongoing', 'JJ'), ('basis', 'NN'), ('ensuring', 'VBG'), ('deadlines', 'NNS'), ('met', 'VBD'), ('high', 'JJ'), ('level', 'NN'), ('accuracy', 'NN'), ('assist', 'JJ'), ('projects', 'NNS'), ('specific', 'JJ'), ('data', 'NNS'), ('team', 'NN'), ('well', 'RB'), ('initiatives', 'VBZ'), ('review', 'NN'), ('existing', 'VBG'), ('business', 'NN'), ('processes', 'NNS'), ('identify', 'VBP'), ('improvements', 'NNS'), ('and/or', 'JJ'), ('opportunities', 'NNS'), ('leverage', 'VBP'), ('technology', 'NN'), ('achieve', 'NN'), ('business', 'NN'), ('objectives', 'NNS'), ('document', 'NN'), ('data', 'NNS'), ('integrity', 'NN'), ('processes', 'VBZ'), ('procedures', 'NNS'), ('controls', 'NNS'), ('maintain', 'VBP'), ('data', 'NNS'), ('flow', 'JJ'), ('diagrams', 'NNS'), ('data', 'NNS'), ('dictionary', 'JJ'), ('etc', 'JJ'), ('candidate', 'NN'), ('profile', 'NN'), ('undergraduate', 'JJ'), ('degree', 'NN'), ('commerce', 'NN'), ('finance', 'NN'), ('equivalent', 'JJ'), ('years', 'NNS'), ('investment', 'NN'), ('data', 'NNS'), ('related', 'JJ'), ('experience', 'NN'), ('completion', 'NN'), ('level', 'NN'), ('cfa', 'NN'), ('program', 'NN'), ('asset', 'NN'), ('exposure', 'NN'), ('it/is/compsci', 'JJ'), ('education', 'NN'), ('experience', 'NN'), ('asset', 'NN'), ('knowledge', 'NN'), ('financial', 'JJ'), ('instruments', 'NNS'), ('market', 'NN'), ('data', 'NNS'), ('data', 'NNS'), ('providers', 'NNS'), ('bloomberg', 'VBP'), ('tsx', 'JJ'), ('etc', 'FW'), ('superior', 'JJ'), ('analytical', 'JJ'), ('skills', 'NNS'), ('attention', 'NN'), ('detail', 'NN'), ('quality', 'NN'), ('high', 'JJ'), ('level', 'NN'), ('proficiency', 'NN'), ('ms', 'NNP'), ('office', 'NN'), ('applications', 'NNS'), ('focus', 'VBP'), ('excel', 'RB'), ('demonstrated', 'VBN'), ('ability', 'NN'), ('work', 'NN'), ('collaboratively', 'RB'), ('cross', 'JJ'), ('functional', 'JJ'), ('teams', 'NNS'), ('especially', 'RB'), ('teams', 'VBP'), ('strong', 'JJ'), ('ability', 'NN'), ('adapt', 'NN'), ('complex', 'JJ'), ('changing', 'VBG'), ('environment', 'NN'), ('excellent', 'JJ'), ('interpersonal', 'JJ'), ('communications', 'NNS'), ('organizational', 'JJ'), ('skills', 'NNS'), ('able', 'JJ'), ('work', 'NN'), ('independently', 'RB'), ('pressure', 'JJ'), ('accountability', 'NN'), ('practical', 'JJ'), ('knowledge', 'NN'), ('financial', 'JJ'), ('services', 'NNS'), ('backoffice', 'NN'), ('/middle', 'NNP'), ('office', 'NN'), ('processes', 'VBZ'), ('systems', 'NNS'), ('ability', 'NN'), ('perform', 'VBP'), ('fast', 'RB'), ('paced', 'VBN'), ('deadlineoriented', 'VBN'), ('environment', 'NN'), ('comfortable', 'JJ'), ('basic', 'JJ'), ('database', 'NN'), ('query', 'NN'), ('language', 'NN'), ('apply', 'VB'), ('position', 'NN'), ('email', 'NN'), ('cover', 'NN'), ('letter', 'NN'), ('resume', 'VBP'), ('careers', 'NNS'), ('@', 'VBP'), ('cclgroupcom',  ...

# %% [markdown]
# ### filtering nouns out of all the words

# %%
filtered_pos = [ ]

# %%
for one in tokens_pos_tag:
    if one[1] == 'NN' or one[1] == 'NNS' or one[1] == 'NNP' or one[1] == 'NNPS':
        filtered_pos.append(one)

# %%
print (len(filtered_pos))
# Out:
# 3631

# %% [markdown]
# ### Finding most frequent words

# %%
fdist_pos = nltk.FreqDist(filtered_pos)

# %%
top_100_words = fdist_pos.most_common(100)

# %%
print(top_100_words)
# Out:
# [(('data', 'NNS'), 236), (('experience', 'NN'), 117), (('skills', 'NNS'), 83), (('ability', 'NN'), 83), (('business', 'NN'), 73), (('analysis', 'NN'), 51), (('work', 'NN'), 48), (('management', 'NN'), 39), (('years', 'NNS'), 35), (('knowledge', 'NN'), 31), (('reports', 'NNS'), 31), (('quality', 'NN'), 29), (('communication', 'NN'), 25), (('support', 'NN'), 25), (('requirements', 'NNS'), 24), (('environment', 'NN'), 23), (('team', 'NN'), 23), (('design', 'NN'), 22), (('product', 'NN'), 22), (('tools', 'NNS'), 22), (('projects', 'NNS'), 21), (('analyst', 'NN'), 20), (('systems', 'NNS'), 20), (('sql', 'NN'), 18), (('project', 'NN'), 18), (('sources', 'NNS'), 17), (('health', 'NN'), 17), (('statistics', 'NNS'), 17), (('process', 'NN'), 17), (('dashboards', 'NNS'), 17), (('asset', 'NN'), 16), (('information', 'NN'), 16), (('office', 'NN'), 16), (('analytics', 'NNS'), 15), (('opportunities', 'NNS'), 15), (('time', 'NN'), 15), (('software', 'NN'), 15), (('computer', 'NN'), 15), (('development', 'NN'), 14), (('science', 'NN'), 14), (('issues', 'NNS'), 14), (('field', 'NN'), 14), (('detail', 'NN'), 14), (('processes', 'NNS'), 14), (('qualifications', 'NNS'), 13), (('customer', 'NN'), 13), (('integrity', 'NN'), 13), (('solutions', 'NNS'), 13), (('insights', 'NNS'), 13), (('performance', 'NN'), 13), (('attention', 'NN'), 13), (('results', 'NNS'), 13), (('problems', 'NNS'), 13), (('report', 'NN'), 12), (('teams', 'NNS'), 12), (('degree', 'NN'), 12), (('marketing', 'NN'), 12), (('market', 'NN'), 12), (('mathematics', 'NNS'), 11), (('problem', 'NN'), 11), (('findings', 'NNS'), 11), (('client', 'NN'), 11), (('company', 'NN'), 11), (('position', 'NN'), 11), (('users', 'NNS'), 11), (('techniques', 'NNS'), 11), (('engineering', 'NN'), 10), (('reporting', 'NN'), 10), (('functions', 'NNS'), 10), (('databases', 'NNS'), 10), (('presentation', 'NN'), 10), (('metrics', 'NNS'), 10), (('system', 'NN'), 10), (('collection', 'NN'), 10), (('database', 'NN'), 10), (('improvement', 'NN'), 10), (('ms', 'NN'), 9), (('research', 'NN'), 9), (('trends', 'NNS'), 9), (('sets', 'NNS'), 9), (('excel', 'NN'), 9), (('analyses', 'NNS'), 9), (('recommendations', 'NNS'), 9), (('job', 'NN'), 9), (('plan', 'NN'), 8), (('queries', 'NNS'), 8), (('clients', 'NNS'), 8), (('stakeholders', 'NNS'), 8), (('execution', 'NN'), 8), (('needs', 'NNS'), 8), (('operations', 'NNS'), 8), (('manage', 'NN'), 8), (('level', 'NN'), 8), (('r', 'NN'), 8), (('organization', 'NN'), 7), (('order', 'NN'), 7), (('industry', 'NN'), 7), (('python', 'NN'), 7), (('education', 'NN'), 7), (('initiatives', 'NNS'), 7)]

# %%
top_words_df = pd.DataFrame(top_100_words, columns = ('pos','count'))

# %%
top_words_df.head()
# Out:
#                 pos  count
# 0       (data, NNS)    236
# 1  (experience, NN)    117
# 2     (skills, NNS)     83
# 3     (ability, NN)     83
# 4    (business, NN)     73

# %%
top_words_df['Word'] = top_words_df['pos'].apply(lambda x: x[0]) # split the tuple of POS

# %%
top_words_df = top_words_df.drop('pos', 1) # drop the previous column

# %%
top_words_df.head()
# Out:
#    count        Word
# 0    236        data
# 1    117  experience
# 2     83      skills
# 3     83     ability
# 4     73    business

# %%
subset_pos = top_words_df[['Word', 'count']]

# %%
tuples_pos = [tuple(x) for x in subset_pos.values]

# %%
wordcloud = WordCloud()

# %%
wordcloud.generate_from_frequencies(tuples_pos)

# %%
plt.figure(figsize=(20,15))
plt.imshow(wordcloud, interpolation="bilinear")

plt.show()

# %% [markdown]
# ### Finding most frequent phrases

# %% [markdown]
# #### _For filtering the bigrams and trigrams, we should consider the original text (before cleaning it) as removing stop-words, numbers or punctuation breaks the original sentences._

# %% [markdown]
# #### Bigrams

# %%
bgs = nltk.bigrams(tokens)

# %%
fdist2 = nltk.FreqDist(bgs) # selecting bigrams from tokens

# %%
bgs_100 = fdist2.most_common(100) # top-100 bigrams

# %%
bgs_df = pd.DataFrame(bgs_100, columns = ('bigram','count'))

# %%
bgs_df.head()
# Out:
#                bigram  count
# 0       (ability, to)     79
# 1            (,, and)     74
# 2  (experience, with)     41
# 3             (in, a)     35
# 4          (to, work)     28

# %%
bgs_df['phrase'] = bgs_df['bigram'].apply(lambda x: x[0]+" "+x[1]) # merging the tuple into a string

# %%
bgs_df['filter_bgs'] = bgs_df['phrase'].str.contains(punctuation) # finding strings with numbers and punctuation

# %%
bgs_df.head()
# Out:
#                bigram  count           phrase  filter_bgs
# 0       (ability, to)     79       ability to       False
# 1            (,, and)     74            , and        True
# 2  (experience, with)     41  experience with       False
# 3             (in, a)     35             in a       False
# 4          (to, work)     28          to work       False

# %%
bgs_df = bgs_df[bgs_df.filter_bgs == False] # removing strings with numbers and punctuation

# %%
bgs_df = bgs_df.drop('bigram', 1)
bgs_df = bgs_df.drop('filter_bgs', 1) # removing the excess columns

# %%
bgs_df.reset_index()
bgs_df.head(10) #Final bigrams
# Out:
#     count            phrase
# 0      79        ability to
# 2      41   experience with
# 3      35              in a
# 4      28           to work
# 5      26      knowledge of
# 6      26          years of
# 7      22           such as
# 8      22           of data
# 9      21          and data
# 10     20  understanding of

# %% [markdown]
# #### Trigrams

# %%
tgs = nltk.trigrams(tokens)

# %%
fdist3 = nltk.FreqDist(tgs) # selecting trigrams from tokens

# %%
tgs_100 = fdist3.most_common(100) # top-100 trigrams

# %%
tgs_df = pd.DataFrame(tgs_100, columns = ('trigram','count'))

# %%
tgs_df.head()
# Out:
#                    trigram  count
# 0      (ability, to, work)     14
# 1  (attention, to, detail)     13
# 2       (the, ability, to)     13
# 3  (years, of, experience)     10
# 4   (computer, science, ,)      9

# %%
tgs_df['phrase'] = tgs_df['trigram'].apply(lambda x: x[0]+" "+x[1]+" "+x[2]) # merging the tuple into a string

# %%
tgs_df['filter_tgs'] = tgs_df['phrase'].str.contains(punctuation) # finding strings with numbers and punctuation

# %%
tgs_df.head()
# Out:
#                    trigram  count               phrase  filter_tgs
# 0      (ability, to, work)     14      ability to work       False
# 1  (attention, to, detail)     13  attention to detail       False
# 2       (the, ability, to)     13       the ability to       False
# 3  (years, of, experience)     10  years of experience       False
# 4   (computer, science, ,)      9   computer science ,        True

# %%
tgs_df = tgs_df[tgs_df.filter_tgs == False] # removing strings with numbers and punctuation

# %%
tgs_df = tgs_df.drop('trigram', 1)
tgs_df = tgs_df.drop('filter_tgs', 1) # removing the excess columns

# %%
tgs_df.reset_index()
tgs_df.head(20) #Final trigrams
# Out:
#     count                        phrase
# 0      14               ability to work
# 1      13           attention to detail
# 2      13                the ability to
# 3      10           years of experience
# 6       8                    to work in
# 8       7                    as well as
# 10      6                a data analyst
# 11      6         to work independently
# 12      6          working knowledge of
# 13      6                  able to work
# 14      6  written communication skills
# 15      6               experience as a
# 16      6              with the ability
# 17      6       demonstrated ability to
# 18      6           experience with sql
# 19      6                     as a data
# 20      5                 tools such as
# 21      5           strong knowledge of
# 22      5              ability to learn
# 23      5           in computer science

# %% [markdown]
# ### _— Abhishek Chhibber_
